# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set_style('whitegrid')
# %matplotlib inline
#from pandas.io.data import DataReader
from pandas_datareader import data, wb, DataReader
#import  pandas_datareader as datareader
from datetime import datetime

# %%
odata=pd.DataFrame(pd.read_csv("oceantempdata.csv"))

# %%
#odata.columns.index=odata["year"]

# %%
odata=odata.set_index('year')

# %%
odata.head()
# Out:
#       W/M^2   OHU  deg C
# year
# 1970   1.31 -6.84   0.03
# 1971   1.35 -5.63  -0.09
# 1972   1.38 -4.77   0.01
# 1973   1.42 -4.09   0.16
# 1974   1.45 -3.35  -0.08

# %%
sns.pairplot(odata)

# %%
odata[:].plot(subplots=False, figsize=(10,5) )
