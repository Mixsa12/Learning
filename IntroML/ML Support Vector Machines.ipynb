# %%
# The Usual Suspects
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
import math

sns.set_style("whitegrid")
#ML libs
import sklearn
from sklearn.svm import SVC
from sklearn.model_selection  import train_test_split
from sklearn import metrics, datasets, svm 

import statsmodels.api as sm  
# %matplotlib inline

# %%
SVCmodel.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
iris = datasets.load_iris()
X = iris.data
Y = iris.target

# %%
SVCmodel = SVC()

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y)

# %%
Y_pred = SVCmodel.predict(X_test)

# %%
print(metrics.accuracy_score(Y_test, Y_pred))
# Out:
# 0.9736842105263158

# %%
X2 = iris.data[:,:2]
Y2 = iris.target  
C= 1.0

# %%
SVCmodel2 = SVC(kernel= 'linear', C=C).fit(X2,Y2)

# %%
RBF_SVC_Model= SVC(kernel= 'rbf', gamma = 0.7,  C=C).fit(X2,Y2)

# %%
POLY_SVC_Model= SVC(kernel= 'poly', degree =3,  C=C).fit(X2,Y2)

# %%
lin_SVC_Model= svm.LinearSVC(  C=C).fit(X2,Y2)

# %%
h= 0.02
x_min = X2[:,0].min() - 1
x_max = X2[:,0].max() + 1
y_min = X2[:,1].min() - 1
y_max = X2[:,1].max() + 1

xx,yy = np.meshgrid(np.arange(x_min,x_max, h), np.arange(y_min,y_max, h))

# %%
titiles = ['SVC with linear kernel','linearSVc','SVC RBF ','SVC poly', ]

# %%
for i,clf in enumerate((SVCmodel2,lin_SVC_Model,RBF_SVC_Model,POLY_SVC_Model)):
    plt.figure(figsize=(15,15))
    plt.subplot(2,2, i +1)
    plt.subplots_adjust(wspace = 0.4, hspace=0.4)
    z= clf.predict(np.c_[xx.ravel(), yy.ravel()])
    z= z.reshape(xx.shape)
    plt.contourf(xx,yy,z, cmap= plt.cm.terrain, alpha =.4 )
    plt.scatter(X2[:,0],X2[:,1], c = Y, cmap =plt.cm.Dark2)
    
    plt.xlim(xx.min(), xx.max()) 
    plt.ylim(yy.min(), yy.max())
